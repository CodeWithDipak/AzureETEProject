# %% [markdown]
# #### Dump all data to the gold container

# %%
df_user = spark.read.table('goldcatalog.goldschema.dimdate')
df_user.write.format('delta')\
    .mode('append')\
        .save('abfss://gold@azureprojectetestorage.dfs.core.windows.net/dimdate')

# %%
df_user = spark.read.table('goldcatalog.goldschema.dimtrack')
df_user.write.format('delta')\
    .mode('append')\
        .save('abfss://gold@azureprojectetestorage.dfs.core.windows.net/dimtrack')

# %%
df_user = spark.read.table('goldcatalog.goldschema.dimuser')
df_user.write.format('delta')\
    .mode('append')\
        .save('abfss://gold@azureprojectetestorage.dfs.core.windows.net/dimuser')

# %%
df_user = spark.read.table('goldcatalog.goldschema.factstream')
df_user.write.format('delta')\
    .mode('append')\
        .save('abfss://gold@azureprojectetestorage.dfs.core.windows.net/factstream')
